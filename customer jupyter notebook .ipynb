# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("customer.csv")

# %%
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # no null values in the dataset

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
sns.countplot(df['1Gender of respondent'],data=df)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# more females are active over online shoping

# %%
plt.figure(figsize=(8,8))

sns.countplot(df['2 How old are you? '],data=df,hue='1Gender of respondent')
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %% [markdown]
# more people are active in 31to40 years of age and mostly females are active

# %%
plt.figure(figsize=(9,9))

sns.countplot(df['3 Which city do you shop online from?'],data=df)
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %% [markdown]
# delhi and greater noida has the highest shoppers

# %%
sns.countplot(df['5 Since How Long You are Shopping Online ?'],data=df,hue='1Gender of respondent')
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %% [markdown]
# max are shoping since 4 years and above and females are mostly active

# %%
plt.figure(figsize=(10,10))

sns.countplot(df['6 How many times you have made an online purchase in the past 1 year?'],data=df)
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %% [markdown]
# people usually open or shop for less in last 1 year

# %%
plt.figure(figsize=(6,6))

sns.countplot(df['7 How do you access the internet while shopping on-line?'],data=df)
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %% [markdown]
# mostly use the mobile internet while do the shopping

# %%
plt.figure(figsize=(6,6))

sns.countplot(df['8 Which device do you use to access the online shopping?'],data=df)
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %% [markdown]
# mostly use the smartphone while do the shopping

# %%
for i in df.columns:
    plt.figure(figsize=(25,25))

    sns.countplot(df[i])

# %%
m = {'Listen' :'Music', 'Play' : 'Games'}
n = list(m.items())
print(n)
# Out:
# [('Listen', 'Music'), ('Play', 'Games')]

# %%
m = 90
n = 7
print(m % n)
# Out:
# 6

# %%
m = 10*10**1
print(m)
# Out:
# 100

# %%
m = [25, 34, 70, 63]
n = str(m[1]) +str(m[2])
print(n)
# Out:
# 3470

# %%
m = open('games.txt', 'w')
m
# Out:
# <_io.TextIOWrapper name='games.txt' mode='w' encoding='cp1252'>

# %%
m = True
n = False
print(m or n)
# Out:
# True

# %%
m = {'Listen' :'Music', 'Play' : 'Games'}
n = m['Music']
print(n)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-354673f52388> in <module>
#       1 m = {'Listen' :'Music', 'Play' : 'Games'}
# ----> 2 n = m['Music']
#       3 print(n)
#
# KeyError: 'Music'

# %%
a = input(-3)
# Out:
# -3-3

# %%
type(a)
# Out:
# str

# %%
m = 'Play Games'
n = m[:]
print(n)
# Out:
# Play Games

# %%
m = ['July', 'September', 'December']

# %%
type(m)
# Out:
# list

# %%
m = [4, 8]
print(m * 3)
# Out:
# [4, 8, 4, 8, 4, 8]

# %%
m = {'m','n','o','p'}
if 'n' in m:
    print('n',end='')
# Out:
# n

# %%
m = 57
n = 19
o = m == n
print(o)
# Out:
# False

# %%
for m in range(6,9):
    print(m,)
    if m == 8:
        break
# Out:
# 6
# 7
# 8

# %%
for m in range(6,9):
    print(m,)
# Out:
# 6
# 7
# 8

# %%
m = 36
if m > 19:
    print(100)
# Out:
# 100

# %%
m = lambda n: n**3
print(m(6))
# Out:
# 216

# %%
m = 9 * (3 + 12)
print(m)
# Out:
# 135

# %%
m = {'A', 'F', 'R', 'Y'}

# %%
type(m)
# Out:
# set

# %%
m = 20
n = 6
m = m * n
print(m)
# Out:
# 120

# %%
m = 70
n = 10
m = m % n
print(m)
# Out:
# 0

# %%
m = [75, 23, 64]
n = m[0] + m[1]
print(n)
# Out:
# 98

# %%
m = ('m', 'n', 'o', 'p')
for n in m:
    print(n, end=' ')
# Out:
# m n o p

# %%
m = []
for n in range(6):
    m.append(n*3)
print(m)
# Out:
# [0, 3, 6, 9, 12, 15]

# %%
(28//6)**3/3%3
# Out:
# 0.33333333333333215

# %%
m = {'Listen' :'Music', 'Play' : 'Games'}

# %%
type(m)
# Out:
# dict

# %%
m = [25, 34, 70, 63]
n = m[2] - m[0]
print(n)
# Out:
# 45

# %%
m = 7 * 5 + 8
m
# Out:
# 43

# %%
m = 17
n = 5
o = m * n
print(o)
# Out:
# 85

# %%
for m in range(7):
    print(m,)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
m = 18
def nop():
    print(m)
    nop()

# %%
nop
# Out:
# <function __main__.nop()>

# %%
m = [50, 25, 65, 0, 99]
n = max(m)
print(n)
# Out:
# 99

# %%
m = [45, 51, 67]
n = m[2]
print(n)
# Out:
# 67

# %%
true = "Honesty is the best policy"
m = true

# %%
type(m)
# Out:
# str

# %%
A panel is a ______ container of data in pandas?   # 3d container
# Out:
#   File "<ipython-input-83-aadcb4e89f6f>", line 1
#     A panel is a ______ container of data in pandas?   # 3d container
#       ^
# SyntaxError: invalid syntax

# %%
#Data structures in Pandas can be mutated in the terms of:
#size
#value

# %%
m = True
n = False
print('not n')
# Out:
# not n

# %%
m = {'Listen' :'Music', 'Play' : 'Games'}
print(m.values())
# Out:
# dict_values(['Music', 'Games'])

# %%
type(m)
# Out:
# dict

# %%
m = False
n = True
o = False
print(m and n and o)
# Out:
# False

# %%
m = [90, 'A', 115, 'B', 250]

# %%
type(m)
# Out:
# list

# %%
m = 92
n = 35
print(m > n)
# Out:
# True

# %%
m = 20 * 10 // 30
n = 20 * 10.0 // 40
o = 20.0 * 10 / 50
print(m, n, o)
# Out:
# 6 5.0 4.0

# %%
None = = None, np.nan = = np.nan
# Out:
#   File "<ipython-input-93-d8104acc720a>", line 1
#     None = = None, np.nan = = np.nan
#            ^
# SyntaxError: invalid syntax

# %%
m = False
n = True
print(m and n)
# Out:
# False

# %%
for m in range(2,9,3):
    print(m,)
# Out:
# 2
# 5
# 8

# %%
m = 'A'
n = 'B'
o = 'C'
p = [m, n, o]
print(p)
# Out:
# ['A', 'B', 'C']

# %%
m = list(range(7,10))
print(m)
# Out:
# [7, 8, 9]

# %%
m = 33
if m > 33:
    print('A')
elif m == 30:
    print('B')
else:
    print('C')
# Out:
# C

# %%
def abc(m, n) :
    return m * n
print(abc(7, 3))
# Out:
# 21

# %%
m = 81 + 34
print(m)
# Out:
# 115

# %%
7 * 4 + 9 - 2 / 3
# Out:
# 36.333333333333336

# %%
a = input('enter an integer ')
# Out:
# enter an integer -3

# %%
type(a)
# Out:
# str

# %%
m = 200
if m = 200:
    print("AA")
elif m = 150:
    print("BB")
elif m = 100:
    print("CC")
else:
    print("DD")
# Out:
#   File "<ipython-input-106-afaa060ff18d>", line 2
#     if m = 200:
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
s=pd.Series(np.random.randn(4))
print(s.ndim)
# Out:
# 1

# %%
m = [90, 'A', 115, 'B', 250]

# %%
m
# Out:
# [90, 'A', 115, 'B', 250]

# %%
type(m)
# Out:
# list

# %%
None = = None, np.nan = = np.nan
# Out:
#   File "<ipython-input-111-d8104acc720a>", line 1
#     None = = None, np.nan = = np.nan
#            ^
# SyntaxError: invalid syntax

# %%
for m in range(6,9):
    if m == 8:
        continue
print(m,)
# Out:
# 8

# %%
m = 'A'
n = 'B'
o = 'C'
p = [m, n, o]
print(p)
# Out:
# ['A', 'B', 'C']

# %%
m = False
n = True
o = False
print(m and n and o)
# Out:
# False

# %%
for i in range(3, 7):
    print('Music')
# Out:
# Music
# Music
# Music
# Music

# %%
m = [25, 34, 70, 63]
n = str(m[1]) +str(m[2])
print(n)
# Out:
# 3470

# %%
m = ('m', 'n', 'o', 'p')
for n in m:
    print(n, end=' ')
# Out:
# m n o p

# %%
m = 'ABC'
for i in m:
    print(i, end=' ')
# Out:
# A B C
